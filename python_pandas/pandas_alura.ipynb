# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados = pd.read_csv(url, sep=';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados[['Quartos','Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %%
dados.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %%
dados['Valor'].mean()
# Out:
# 12952.659715265761

# %%
dados.groupby('Tipo').mean(numeric_only=True) #unicamente nas colunas numéricas
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
dados.groupby('Tipo')['Valor'].mean() #Apenas na coluna valor
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados.groupby('Tipo')[['Valor']].mean() #Apenas na coluna valor
# Out:
#                                      Valor
# Tipo
# Apartamento                    4744.614648
# Box/Garagem                    1899.756098
# Casa                           6793.454922
# Casa Comercial                14478.264151
# Casa de Condomínio            11952.061245
# Casa de Vila                   1574.369478
# Chácara                        4900.000000
# Conjunto Comercial/Sala       14715.045521
# Flat                           4546.189076
# Galpão/Depósito/Armazém       53407.062600
# Hotel                         25000.000000
# Indústria                    120000.000000
# Loft                           2557.882353
# Loja Shopping/ Ct Comercial    8126.178862
# Loja/Salão                    13769.646770
# Loteamento/Condomínio         22000.000000
# Pousada/Chalé                  1480.000000
# Prédio Inteiro               498637.239203
# Quitinete                      1246.840909
# Studio                         2400.000000
# Sítio                         12499.000000
# ...

# %%
dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

df_preco_tipo.plot(kind='barh', figsize=(14,8), color='purple')
# Out:
# <AxesSubplot:ylabel='Tipo'>

# %% [markdown]
# O método groupby do Pandas permite agrupar e resumir dados de um DataFrame, com base em um ou mais critérios. Esses critérios podem ser variáveis numéricas ou categóricas, como colunas ou índices do DataFrame.
#
# A ideia por trás do groupby é dividir os dados em grupos com base nos critérios selecionados e, em seguida, aplicar uma operação a esses grupos. Essa operação pode ser uma função de agregação, como soma, média, contagem, desvio padrão, entre outras, ou mesmo uma operação personalizada definida pela pessoa usuária.
#
# Esse método possui diversos parâmetros, alguns deles são:
#
# by: esse é o parâmetro mais comum e é usado para especificar a coluna ou colunas que queremos agrupar. Como argumento dele, podemos passar o nome de uma coluna ou uma lista de nomes de colunas;
#
# axis: utilizamos esse parâmetro para especificar o eixo ao longo do qual queremos agrupar. O valor padrão dele é 0, o que significa que as linhas serão agrupadas. Se quisermos agrupar as colunas, devemos definir esse parâmetro como 1;
#
# sort: esse parâmetro é um booleano (True ou False) que indica se os grupos devem ser ordenados pelo valor da coluna de agrupamento. O valor padrão é True;
#
# dropna: utilizamos esse parâmetro para controlar se os valores ausentes (NaN) serão excluídos ou não durante o processo de agrupamento. O valor padrão é True.

# %%
df = pd.DataFrame({
    'Animal':['Cachorro','Gato','Elefante','Cahorro','Gato','Elefante'],
    'Cor':['Preto','Branco','Cinza','Marrom','Preto','Marrom'],
    'Quantidade': [2,3,1,4,2,2]
})
df
# Out:
#      Animal     Cor  Quantidade
# 0  Cachorro   Preto           2
# 1      Gato  Branco           3
# 2  Elefante   Cinza           1
# 3   Cahorro  Marrom           4
# 4      Gato   Preto           2
# 5  Elefante  Marrom           2

# %%
df.groupby('Animal').sum(numeric_only=True)
# Out:
#           Quantidade
# Animal
# Cachorro           2
# Cahorro            4
# Elefante           3
# Gato               5

# %%
df.groupby(['Animal','Cor'])[['Quantidade']].sum()
# Out:
#                  Quantidade
# Animal   Cor
# Cachorro Preto            2
# Cahorro  Marrom           4
# Elefante Cinza            1
#          Marrom           2
# Gato     Branco           3
#          Preto            2

# %% [markdown]
# ## Removendo os imóveis comerciais

# %%
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala','Prédio Inteiro','Loja/Salão',
                    'Galpão/Depósito/Armazém', 'Casa Comercial','Terreno Padrão',
                    'Box/Garagem', 'Chácara', 'Loteamento/Condomínio',
                    'Sítio', 'Pousada/Chalé','Hotel', 'Indústria']

# %%
dados.query("@imoveis_comerciais in Tipo")#vARIAVEL PRECISA DE @
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
df = dados.query('@imoveis_comerciais not in Tipo')#not, oposto do in

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Loja Shopping/ Ct Comercial', 'Studio'],
#       dtype=object)

# %%
df
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo') #converte a series para df Formato percentual
# Out:
#                                  Tipo
# Studio                       0.000171
# Loft                         0.002183
# Loja Shopping/ Ct Comercial  0.010575
# Casa de Vila                 0.010660
# Flat                         0.020378
# Quitinete                    0.035791
# Casa                         0.041399
# Casa de Condomínio           0.042641
# Apartamento                  0.836202

# %%
df_percentual_tipo = df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')

df_percentual_tipo.plot(kind='bar', figsize=(10, 5), color='green', xlabel='Tipos', ylabel='Percentural')
# Out:
# <AxesSubplot:xlabel='Tipos', ylabel='Percentural'>

# %%
#Selecionando apenas os imoveis do tipo apartamento
df.query('Tipo == "Apartamento"')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %% [markdown]
# O time de ML chegou com algumas demandas de última hora para resolvermos nesse momento da análise exploratória. Essas demandas são:
#
# 1) Calcular a média de quartos por apartamento;
#
# 2) Conferir quantos bairros únicos existem na nossa base de dados;
#
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
#
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
#1) Calcular a média de quartos por apartamento;
print(dados.Tipo.unique())
dados_apartamento = dados.query('Tipo == "Apartamento"')
display(dados_apartamento)
dados_apartamento['Quartos'].mean()
# Out:
# ['Quitinete' 'Casa' 'Conjunto Comercial/Sala' 'Apartamento'
#  'Casa de Condomínio' 'Prédio Inteiro' 'Flat' 'Loja/Salão'
#  'Galpão/Depósito/Armazém' 'Casa Comercial' 'Casa de Vila'
#  'Terreno Padrão' 'Box/Garagem' 'Loft' 'Loja Shopping/ Ct Comercial'
#  'Chácara' 'Loteamento/Condomínio' 'Sítio' 'Pousada/Chalé' 'Studio'
#  'Hotel' 'Indústria']
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# ...

# %%
#2) Conferir quantos bairros únicos existem na nossa base de dados;
len(dados.Bairro.unique())
# Out:
# 162

# %%
#3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
display(dados)

medias = dados.groupby('Bairro')['Valor'].mean()

medias = medias.reset_index()

medias = medias.sort_values('Valor', ascending=False)
medias
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
#4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

df_bairros_caros = medias.head(5)
display(df_bairros_caros)

import matplotlib.pyplot as plt

df_bairros_caros.plot(kind='barh', figsize=(10,5), color='purple', xlabel='Bairro', ylabel='Valor')
plt.show()
# Out:
#             Bairro          Valor
# 70     Jacarepaguá  314143.489637
# 66           Irajá  154610.470588
# 18            Caju  120264.782609
# 149  Vasco da Gama  120000.000000
# 29     Cidade Nova   88166.692308

# %% [markdown]
# # Tratando dados nulos

# %%
dados.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32955  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
# 32959  False   False    False  False   False  False  False       False  False
#
# [32960 rows x 9 columns]

# %%
dados.isnull().sum()
# Out:
# Tipo              0
# Bairro            0
# Quartos           0
# Vagas             0
# Suites            0
# Area              0
# Valor            17
# Condominio     4093
# IPTU          10237
# dtype: int64

# %%
dados.fillna(0)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# # Remover registros incossistentes
# ## Aluguel e condomínio igual a zero

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
# Substitua os valores NaN por 0
dados = dados.fillna(0)

# %%
dados.query('Valor == 0 | Condominio == 0')
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 5             Apartamento             Vista Alegre        3      1       0
# 7      Casa de Condomínio          Barra da Tijuca        5      4       5
# 8      Casa de Condomínio                    Ramos        2      2       0
# 10            Apartamento                   Centro        1      0       0
# ...                   ...                      ...      ...    ...     ...
# 32914          Loja/Salão             Campo Grande        0      0       0
# 32928          Loja/Salão                   Leblon        0      0       0
# 32929          Loja/Salão  Freguesia (Jacarepaguá)        0      0       0
# 32931                Casa                   Centro        5      0       1
# 32954         Box/Garagem                   Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# ...

# %%
dados.query('Valor == 0 | Condominio == 0').index
# Out:
# Int64Index([    1,     5,     7,     8,    10,    16,    18,    31,    35,
#                76,
#             ...
#             32893, 32897, 32899, 32911, 32912, 32914, 32928, 32929, 32931,
#             32954],
#            dtype='int64', length=4106)

# %%
registros_a_remover = dados.query('Valor == 0 | Condominio == 0').index

# %%
dados.drop(registros_a_remover, axis=0, inplace=True)

# %%
dados.query('Valor == 0 | Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 6              Apartamento         Cachambi        2      0       0    50
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     0.0
# 6  1300.0       301.0    17.0

# %%
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Conjunto Comercial/Sala', 'Apartamento', 'Flat',
#        'Casa de Condomínio', 'Loja/Salão', 'Casa', 'Casa Comercial',
#        'Casa de Vila', 'Loft', 'Loja Shopping/ Ct Comercial',
#        'Galpão/Depósito/Armazém', 'Prédio Inteiro', 'Box/Garagem',
#        'Pousada/Chalé', 'Studio', 'Terreno Padrão'], dtype=object)

# %%
dados.drop('Tipo', axis=1, inplace=True)

# %%
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %% [markdown]
# # 1. Apartamentos que possuem 1 quarto e aluguel menor que 120

# %%
dados['Quartos'] == 1
# Out:
# 0         True
# 2        False
# 3         True
# 4         True
# 6        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959    False
# Name: Quartos, Length: 28854, dtype: bool

# %%
selecao1 = df['Quartos'] == 1
df[selecao1]
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0        Quitinete       Copacabana        1      0       0    40  1700.0
# 3      Apartamento           Centro        1      0       0    15   800.0
# 4      Apartamento     Higienópolis        1      0       0    48   800.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 13     Apartamento       Copacabana        1      0       1    40  2000.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32922  Apartamento  Barra da Tijuca        1      1       0    62  1700.0
# 32935  Apartamento           Leblon        1      1       1    50  4300.0
# 32938  Apartamento       Copacabana        1      0       0    50  1950.0
# 32945    Quitinete       Copacabana        1      0       0    22  1500.0
# 32950  Apartamento           Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 0           500.0   60.0
# 3           390.0   20.0
# ...

# %%
selecao2 = df['Valor'] < 1200
df[selecao2]
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 3             Apartamento                   Centro        1      0       0
# 4             Apartamento             Higienópolis        1      0       0
# 8      Casa de Condomínio                    Ramos        2      2       0
# 19            Apartamento  Freguesia (Jacarepaguá)        3      0       0
# 23            Apartamento                   Olaria        3      1       0
# ...                   ...                      ...      ...    ...     ...
# 32930         Apartamento  Freguesia (Jacarepaguá)        2      1       0
# 32950         Apartamento                   Tijuca        1      0       0
# 32951         Apartamento           Vila Valqueire        2      0       0
# 32953         Apartamento                    Méier        2      0       0
# 32955           Quitinete                   Centro        0      0       0
#
#        Area   Valor  Condominio   IPTU
# ...

# %%
selecao_final = (selecao1) & (selecao2)
df[selecao_final]
# Out:
#               Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento        Centro        1      0       0    15   800.0
# 4      Apartamento  Higienópolis        1      0       0    48   800.0
# 28     Apartamento        Tijuca        1      0       0    48   750.0
# 54     Apartamento        Centro        1      0       0    27   750.0
# 94     Apartamento        Centro        1      1       0    37  1100.0
# ...            ...           ...      ...    ...     ...   ...     ...
# 32763    Quitinete        Glória        1      0       0    10   400.0
# 32818    Quitinete      Flamengo        1      0       0    23   900.0
# 32844    Quitinete        Centro        1      0       0    24  1100.0
# 32859         Casa  Campo Grande        1      0       0    50   600.0
# 32950  Apartamento        Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    NaN
# 28          772.0   25.0
# ...

# %% [markdown]
# # 2. Apartamentos que possuem pelo menos 2 quartos, aluguel menor que 3000 e area maior que 70

# %%
selecao = (df['Quartos'] >= 2) & (df['Valor'] < 3000) & (df['Area'] > 70)
df[selecao]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 12            Apartamento       Lins de Vasconcelos        3      1       1
# 18     Casa de Condomínio                   Taquara        3      1       1
# 21            Apartamento                    Tijuca        2      1       0
# 24            Apartamento                    Tijuca        2      1       0
# 32            Apartamento                  Botafogo        2      1       0
# ...                   ...                       ...      ...    ...     ...
# 32934         Apartamento               Jacarepaguá        2      1       1
# 32940         Apartamento           Barra da Tijuca        2      1       1
# 32941         Apartamento           Barra da Tijuca        3      2       0
# 32944         Apartamento  Recreio dos Bandeirantes        3      2       1
# 32956         Apartamento               Jacarepaguá        3      1       2
#
#        Area   Valor  Condominio   IPTU
# ...

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar alguns tratamentos e seleções utilizando um arquivo csv diferente: alunos.csv.
#
# Esse arquivo é o mesmo utilizado para resolução dos desafios da aula 1 e possui dados referentes a alunos de um curso superior.
#
# Com base nisso, solucione os problemas propostos abaixo utilizando os conhecimentos adquiridos até aqui.
#
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.
#
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
#
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
#
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".
#
# Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
import pandas as pd
data = [
    ("Ary", 20, 7.5, True),
    ("Ana", 18, None, False),
    ("Cátia", 27, 2.5, False),
    ("Denis", 18, 5.0, False),
    ("Beto", 21, 10.0, True),
    ("Bruna", 23, None, False),
    ("Dara", 21, 7.0, True),
    ("Carlos", 19, 6.0, True),
    ("Alice", 35, 5.6, False),
    ("Vitor", 28, None, False),
    ("Daniel", 21, None, False),
    ("Igor", 24, 4.5, False),
    ("Sthefanie", 26, 9.5, True),
    ("Mirla", 25, 9.0, True),
    ("Paulo", 37, None, False),
    ("Mylena", 29, 7.0, True),
    ("Lucas", 33, None, False),
    ("Nadia", 34, 8.0, True)
]
df = pd.DataFrame(data, columns=["Nome", "Idade", "Notas", "Aprovado"])
display(df)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos 
# da forma que achar mais coerente com a situação.

print(df.isnull().sum())
print(df.fillna(0))
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
df_new = df[df['Nome'] != 'Alice']
df_new = df[df['Nome'] != 'Carlos']
df_new
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
df_aprova = df[df['Aprovado'] == True]
df_aprova
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".
df_aprova.to_csv('alunos_aprovados.csv')
